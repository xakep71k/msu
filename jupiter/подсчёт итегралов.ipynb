# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.linspace(-1, 10, 1001)
x_for_ln = np.linspace(0.001, 10, 1001)

plt.grid()
plt.xlabel('x',fontsize=8)
plt.ylabel('log',fontsize=8)

plt.plot(x_for_ln, np.log(x_for_ln), label='1/ln(x)')
plt.legend()
plt.ylim(-10, 10)
# Out:
# (-10.0, 10.0)
